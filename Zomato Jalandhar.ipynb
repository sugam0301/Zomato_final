# %%
import requests
from bs4 import BeautifulSoup

# url = 'https://www.zomato.com/jalandhar/sehgal-fast-food-shastri-nagar'
# headers = {'User-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Mobile Safari/537.36'}
# response = requests.get(url, headers=headers)
# response.status_code

# %%
import pandas as pd

# %%
headers = {'User-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Mobile Safari/537.36'}

# %%
# result_container = soup.find_all('a' )
# result_container

# %%
# a = soup.find('section',{'class':'sc-iGrrsa'}).find_all('span')
# a

# %%
# soup.find_all('a',{'class':'sc-ks3f96-0'})[4].get_text().split('/')[0]

# %%
# soup.find_all('a',{'class':'sc-ks3f96-0'})[3].get_text().split('/')[0]

# %%
# soup.find_all('div',{'class':'sc-1q7bklc-8'})[0].get_text().split(' ')[0]

# %%
import pandas as pd
jal = pd.read_excel("C:\\Users\\Lenovo\\Downloads\\Jalandhar.xlsx",sheet_name = "Sheet3")
jal
# Out:
#                    name         price  \
# 0       Biryani By Kilo  ?400 for one
# 1            Food Bazar  ?400 for one
# 2       Behrouz Biryani  ?400 for one
# 3    Lovely Bake Studio  ?400 for one
# 4       Chick Chick PPR  ?400 for one
# ..                  ...           ...
# 640    Arora Food Court  ?100 for one
# 641   Fish Corner Dhaba  ?100 for one
# 642        Veggie Chaap  ?150 for one
# 643     Bombay Chaupati           NaN
# 644    Sehgal Fast Food  ?150 for one
#
#                                                cuisine reviews  \
# 0                  Biryani, Mughlai, Kebab, Hyderabadi     4.1
# 1    South Indian, Chinese, North Indian, Fast Food...     4.3
# 2                              Biryani, Kebab, Mughlai     4.3
# 3                Bakery, Chinese, Fast Food, Beverages     4.3
# 4              North Indian, Mughlai, Chinese, Seafood     3.9
# ..                                                 ...     ...
# 640                                       North Indian       4
# 641                              North Indian, Mughlai     3.5
# 642                                Rolls, North Indian     4.1
# 643                             Street Food, Fast Food     3.9
# 644                                    Burger, Chinese     4.4
#
#                                           Location url
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...
# 1    https://www.zomato.com/jalandhar/food-bazar-sh...
# 2    https://www.zomato.com/jalandhar/behrouz-birya...
# 3    https://www.zomato.com/jalandhar/lovely-bake-s...
# 4    https://www.zomato.com/jalandhar/chick-chick-p...
# ..                                                 ...
# 640  https://www.zomato.com/jalandhar/arora-food-co...
# 641  https://www.zomato.com/jalandhar/fish-corner-d...
# 642  https://www.zomato.com/jalandhar/veggie-chaap-...
# 643  https://www.zomato.com/jalandhar/bombay-chaupa...
# 644  https://www.zomato.com/jalandhar/sehgal-fast-f...
#
# [645 rows x 5 columns]

# %%
s = jal["Location url"]
b = s[642]
c = s[0:2]
c
# Out:
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...
# 1    https://www.zomato.com/jalandhar/food-bazar-sh...
# Name: Location url, dtype: object

# %%
def fun(x):
    x = x.replace("/order","")
    return x
jal["Location url"] = jal["Location url"].apply(fun)
jal["reviews"] = jal["reviews"].astype(str)
jal.head()
# Out:
#                  name         price  \
# 0     Biryani By Kilo  ?400 for one
# 1          Food Bazar  ?400 for one
# 2     Behrouz Biryani  ?400 for one
# 3  Lovely Bake Studio  ?400 for one
# 4     Chick Chick PPR  ?400 for one
#
#                                              cuisine reviews  \
# 0                Biryani, Mughlai, Kebab, Hyderabadi     4.1
# 1  South Indian, Chinese, North Indian, Fast Food...     4.3
# 2                            Biryani, Kebab, Mughlai     4.3
# 3              Bakery, Chinese, Fast Food, Beverages     4.3
# 4            North Indian, Mughlai, Chinese, Seafood     3.9
#
#                                         Location url
# 0  https://www.zomato.com/jalandhar/biryani-by-ki...
# 1  https://www.zomato.com/jalandhar/food-bazar-sh...
# 2  https://www.zomato.com/jalandhar/behrouz-birya...
# 3  https://www.zomato.com/jalandhar/lovely-bake-s...
# 4  https://www.zomato.com/jalandhar/chick-chick-p...

# %%
lst = []
for i in s:
    url = i
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    a = soup.find_all('a',{'class':'sc-ks3f96-0'})[4].get_text().split('/')[0]
    print(a)
    lst.append(a)
# Out:
# Urban Estate
# Shastri Nagar
# Shastri Nagar
# Nakodar Road
# PPR Market
# Model Town
# Adarsh Nagar
# Shastri Nagar
# GT Road
# Nakodar Road
# Maqsudan
# Shastri Nagar
# Shastri Nagar
# Shastri Nagar
# Shastri Nagar
# Adarsh Nagar
# Adarsh Nagar
# Shastri Nagar
# GT Road
# Model Town
# Model Town
# Shastri Nagar
# Model Town
# Nakodar Road
# Adarsh Nagar
# Shastri Nagar
# GT Road
# Adarsh Nagar
# Shastri Nagar
# Model Town
# Model Town
# Model Town
# PPR Market
# Shastri Nagar
# Shastri Nagar
# Adarsh Nagar
# Adarsh Nagar
# Shastri Nagar
# Nakodar Road
# Maqsudan
# Adarsh Nagar
# Adarsh Nagar
# Shastri Nagar
# PPR Market
# Shastri Nagar
# Shastri Nagar
# Model Town
# Model Town
# Model Town
# Model Town
# Shastri Nagar
# Urban Estate
# Model Town
# Model Town
# Shastri Nagar
# Shastri Nagar
# Model Town
# PPR Market
# Model Town
# Model House
# Model Town
# Model Town
# Shastri Nagar
# Urban Estate
# Model Town
# Model House
# PPR Market
# PPR Market
# Transport Nagar
# Nakodar Road
# Model Town
# Adarsh Nagar
# Shastri Nagar
# Shastri Nagar
# Urban Estate
# Model Town
# PPR Market
# GT Road
# Adarsh Nagar
# Shastri Nagar
# Adarsh Nagar
# Shastri Nagar
# Model House
# Shastri Nagar
# Shastri Nagar
# Adarsh Nagar
# PPR Market
# GT Road
# Model Town
# Shastri Nagar
# Model Town
# Shastri Nagar
# Model Town
# Shastri Nagar
# PPR Market
# Maqsudan
# Urban Estate
# Adarsh Nagar
# Shastri Nagar
# Model Town
# Adarsh Nagar
# Model Town
# Model Town
# Nakodar Road
# Nakodar Road
# Nakodar Road
# GT Road
# Urban Estate
# Shastri Nagar
# PPR Market
# Adarsh Nagar
# Urban Estate
# Shastri Nagar
# Nakodar Road
# Transport Nagar
# Shastri Nagar
# Model Town
# PPR Market
# Model Town
# Shastri Nagar
# Adarsh Nagar
# Jalandhar Cantt
# Shastri Nagar
# PPR Market
# PPR Market
# GT Road
# Rama Mandi
# Urban Estate
# Shastri Nagar
# Model Town
# Shastri Nagar
# Shastri Nagar
# Maqsudan
# Maqsudan
# Shastri Nagar
# Model Town
# Maqsudan
# Adarsh Nagar
# Adarsh Nagar
# Model Town
# Model House
# Shastri Nagar
# GT Road
# Shastri Nagar
# Model Town
# Adarsh Nagar
# Adarsh Nagar
# Model Town
# Model Town
# Shastri Nagar
# Adarsh Nagar
# Shastri Nagar
# Nakodar Road
# Shastri Nagar
# Rama Mandi
# Shastri Nagar
# Maqsudan
# GT Road
# Model Town
# Adarsh Nagar
# Maqsudan
# Model Town
# Model Town
# Nakodar Road
# Urban Estate
# Adarsh Nagar
# Adarsh Nagar
# Shastri Nagar
#
# Shastri Nagar
# Shastri Nagar
# Adarsh Nagar
# Jalandhar Cantt
# Adarsh Nagar
# Rama Mandi
# Urban Estate
# Shastri Nagar
# Model House
# Adarsh Nagar
# Model Town
# Urban Estate
# PPR Market
# Jalandhar Cantt
# Urban Estate
# Model Town
# Urban Estate
# Adarsh Nagar
# Jalandhar Cantt
# Model Town
# Model Town
# Nakodar Road
# Model Town
# Adarsh Nagar
# PPR Market
# Model Town
# Model Town
# GT Road
# PPR Market
# Model House
# PPR Market
# PPR Market
# Shastri Nagar
# Adarsh Nagar
# Maqsudan
# Shastri Nagar
# Jalandhar Cantt
# GT Road
# Adarsh Nagar
# Nakodar Road
# Model Town
# PPR Market
# Adarsh Nagar
# PPR Market
# Shastri Nagar
# Adarsh Nagar
# Adarsh Nagar
# Adarsh Nagar
# Rama Mandi
# Shastri Nagar
# Shastri Nagar
# Adarsh Nagar
# Adarsh Nagar
# Adarsh Nagar
# Shastri Nagar
# Shastri Nagar
# Shastri Nagar
# Model Town
# Shastri Nagar

# %%
loc = lst
len(lst)
# Out:
# 645

# %%
reviews = []
url = "https://www.zomato.com/jalandhar/biryani-by-kilo-urban-estate"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.find('section',{'class':'sc-cqCuEk'}).get_text().split('fill')[2].split(' ')[0])
soup.find_all('div',{'class':'sc-1q7bklc-8'})[1].get_text().split(' ')[0]
# Out:
# 3,083
# '3,083'

# %%
lst2 = []
import requests
from bs4 import BeautifulSoup
headers = {'User-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Mobile Safari/537.36'}
s = jal["Location url"]
cnt=0
reviews = jal["reviews"]

for i in s:
    url=i
    print(cnt," - ",url)
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    if reviews[cnt]!="New":
        a = soup.find('section',{'class':'sc-cqCuEk'}).get_text().split('fill')[2].split(' ')[0]
        lst2.append(a)
        print(a)
    else:
        lst2.append("0")
        print("0")
    cnt+=1
# Out:
# 0  -  https://www.zomato.com/jalandhar/biryani-by-kilo-urban-estate
# 3,083
# 1  -  https://www.zomato.com/jalandhar/food-bazar-shastri-nagar
# 40.5K
# 2  -  https://www.zomato.com/jalandhar/behrouz-biryani-shastri-nagar
# 900
# 3  -  https://www.zomato.com/jalandhar/lovely-bake-studio-nakodar-road
# 9,438
# 4  -  https://www.zomato.com/jalandhar/chick-chick-ppr-ppr-market
# 20.2K
# 5  -  https://www.zomato.com/jalandhar/aggarwal-vaishno-dhaba-1-model-town
# 33.9K
# 6  -  https://www.zomato.com/jalandhar/the-pizza-bunker-adarsh-nagar
# 343
# 7  -  https://www.zomato.com/jalandhar/raju-cheese-corner-shastri-nagar
# 11K
# 8  -  https://www.zomato.com/jalandhar/gkc-chaap-plaza-gt-road
# 1,851
# 9  -  https://www.zomato.com/jalandhar/aar-kay-vaishno-dhaba-nakodar-road
# 54K
# 10  -  https://www.zomato.com/jalandhar/maddi-refreshment-1-maqsudan
# 22.3K
# response = requests.get(url, headers=headers)
# soup = BeautifulSoup(response.content, 'html.parser')
# print(reviews[cnt])
# if reviews[cnt]=='New':
#     lst2.append("0")
#     print("0")
# elif reviews[cnt]!="New":
#     a = soup.find('section',{'class':'sc-cqCuEk'}).get_text().split('fill')[2].split(' ')[0]
#     lst2.append(a)
#     print(a)

# %%
jal.iloc[485]

# %%
len(lst2)

# %%
lst2[496]

# %%
# cnt=497
# reviews = jal["reviews"]
# s2 = s[497:]

# for i in s2:
#     url=i
#     print(cnt," - ",url)
#     response = requests.get(url, headers=headers)
#     soup = BeautifulSoup(response.content, 'html.parser')
#     if reviews[cnt]!="New":
#         a = soup.find('section',{'class':'sc-cqCuEk'}).get_text().split('fill')[2].split(' ')[0]
#         lst2.append(a)
#         print(a)
#     else:
#         lst2.append("0")
#         print("0")
#     cnt+=1

# %%
s[520]

# %%
len(lst2)

# %%
lst3 = lst2[0:496]
len(lst3)

# %%
lst2[520]

# %%
jal["location"] = lst
jal["no. of reviews"] = lst2
jal.head()
# Out:
#                  name         price  \
# 0     Biryani By Kilo  ?400 for one
# 1          Food Bazar  ?400 for one
# 2     Behrouz Biryani  ?400 for one
# 3  Lovely Bake Studio  ?400 for one
# 4     Chick Chick PPR  ?400 for one
#
#                                              cuisine reviews  \
# 0                Biryani, Mughlai, Kebab, Hyderabadi     4.1
# 1  South Indian, Chinese, North Indian, Fast Food...     4.3
# 2                            Biryani, Kebab, Mughlai     4.3
# 3              Bakery, Chinese, Fast Food, Beverages     4.3
# 4            North Indian, Mughlai, Chinese, Seafood     3.9
#
#                                         Location url       location  \
# 0  https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 1  https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# 2  https://www.zomato.com/jalandhar/behrouz-birya...  Shastri Nagar
# 3  https://www.zomato.com/jalandhar/lovely-bake-s...   Nakodar Road
# 4  https://www.zomato.com/jalandhar/chick-chick-p...     PPR Market
#
#   no. of reviews
# 0          3,083
# 1          40.5K
# 2            900
# 3          9,438
# 4          20.2K

# %%
jal["cuisine"].value_counts()
# Out:
# North Indian                                                      81
# Street Food                                                       22
# North Indian, Chinese                                             17
# Fast Food                                                         13
# North Indian, Fast Food                                           11
#                                                                   ..
# North Indian, Rolls, Chinese, Beverages                            1
# North Indian, Fast Food, Rolls                                     1
# Healthy Food, Fast Food, North Indian, Beverages, Salad, Shake     1
# North Indian, Chinese, Mughlai, Continental, Beverages             1
# Fast Food, Rolls, Wraps                                            1
# Name: cuisine, Length: 365, dtype: int64

# %%
jal.sample(20)
# Out:
#                                      name         price  \
# 368                     Delicious Kitchen  ?100 for one
# 501                              MP Dhaba  ?100 for one
# 176                 Sandy Sandwich Corner  ?150 for one
# 56                          Bittu Pardesi  ?200 for one
# 93   Super Cremica Fast Food & Restaurant  ?200 for one
# 456                           Egg Express  ?250 for one
# 528                   Momos Dim Sim House  ?350 for one
# 395                Aggarwal Cheese Corner  ?150 for one
# 524                         Hot And Fresh  ?350 for one
# 434               Singh Saab Food Station   ?50 for one
# 383            Hotel Skylark & Restaurant  ?350 for one
# 308                          Singh's Food  ?100 for one
# 308            635
# 323             46
# 441             12
# 113          8,282
# 472             24
# 521              0
# 131            530
# 637            370
# 345            102

# %%
jal.to_excel("ashu_zomato_jalandhar.xlsx")

# %%
a = jal

# %%
a = a.assign(cuisine = a['cuisine'].str.split(',')).explode('cuisine')

# %%
a
# Out:
#                  name         price        cuisine reviews  \
# 0     Biryani By Kilo  ?400 for one        Biryani     4.1
# 0     Biryani By Kilo  ?400 for one        Mughlai     4.1
# 0     Biryani By Kilo  ?400 for one          Kebab     4.1
# 0     Biryani By Kilo  ?400 for one     Hyderabadi     4.1
# 1          Food Bazar  ?400 for one   South Indian     4.3
# ..                ...           ...            ...     ...
# 642      Veggie Chaap  ?150 for one   North Indian     4.1
# 643   Bombay Chaupati           NaN    Street Food     3.9
# 643   Bombay Chaupati           NaN      Fast Food     3.9
# 644  Sehgal Fast Food  ?150 for one         Burger     4.4
# 644  Sehgal Fast Food  ?150 for one        Chinese     4.4
#
#                                           Location url       location  \
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 1    https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# ..                                                 ...            ...
# 642  https://www.zomato.com/jalandhar/veggie-chaap-...  Shastri Nagar
# 643  https://www.zomato.com/jalandhar/bombay-chaupa...     Model Town
# 643  https://www.zomato.com/jalandhar/bombay-chaupa...     Model Town
# 644  https://www.zomato.com/jalandhar/sehgal-fast-f...  Shastri Nagar
# 644  https://www.zomato.com/jalandhar/sehgal-fast-f...  Shastri Nagar
#
#     no. of reviews
# 0            3,083
# 0            3,083
# 0            3,083
# 0            3,083
# 1            40.5K
# ..             ...
# 642             97
# 643            175
# 643            175
# 644            321
# 644            321
#
# [1977 rows x 7 columns]

# %%
a["cuisine"].value_counts()
# Out:
# North Indian        253
#  Fast Food          222
#  Beverages          181
#  Chinese            170
# Fast Food            91
#                    ...
# American              1
#  Panini               1
#  Waffle               1
# Charcoal Chicken      1
#  Arabian              1
# Name: cuisine, Length: 77, dtype: int64

# %%
a.isnull().sum()
# Out:
# name              0
# price             2
# cuisine           0
# reviews           0
# Location url      0
# location          0
# no. of reviews    0
# dtype: int64

# %%
jal = a
jal.to_csv("jalandhar_zomato.csv")

# %%
a["location"].value_counts()
a
# Out:
#      price  cuisine reviews  location no. of reviews
# 0    400.0       50     4.1        11           3083
# 0    400.0       27     4.1        11           3083
# 0    400.0       22     4.1        11           3083
# 0    400.0       17     4.1        11           3083
# 1    400.0       74     4.3         9           40.5
# ..     ...      ...     ...       ...            ...
# 642  150.0       28     4.1         9             97
# 643    NaN       75     3.9         5            175
# 643    NaN       14     3.9         5            175
# 644  150.0       51     4.4         9            321
# 644  150.0        9     4.4         9            321
#
# [1977 rows x 5 columns]

# %%
temp = a
temp.head(10)
# Out:
#               name         price        cuisine reviews  \
# 0  Biryani By Kilo  ?400 for one        Biryani     4.1
# 0  Biryani By Kilo  ?400 for one        Mughlai     4.1
# 0  Biryani By Kilo  ?400 for one          Kebab     4.1
# 0  Biryani By Kilo  ?400 for one     Hyderabadi     4.1
# 1       Food Bazar  ?400 for one   South Indian     4.3
# 1       Food Bazar  ?400 for one        Chinese     4.3
# 1       Food Bazar  ?400 for one   North Indian     4.3
# 1       Food Bazar  ?400 for one      Fast Food     4.3
# 1       Food Bazar  ?400 for one    Street Food     4.3
# 1       Food Bazar  ?400 for one      Beverages     4.3
#
#                                         Location url       location  \
# 0  https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 0  https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 0  https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 0  https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 1  https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# 1  https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# 1  https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# 1  https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# 1  https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# 1  https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
#
#   no. of reviews
# 0          3,083
# 0          3,083
# 0          3,083
# 0          3,083
# 1          40.5K
# 1          40.5K
# 1          40.5K
# 1          40.5K
# 1          40.5K
# 1          40.5K

# %%
temp.drop(columns=["name","Location url"],inplace=True)

# %%
def fun(x):
    x = x.replace("?","")
    x =x.replace(" for one","")
    return x
temp["price"] = temp["price"].astype(str)
temp["price"] = temp["price"].apply(fun)
temp["price"] = temp["price"].astype(float)
temp.head()
# Out:
#    price       cuisine reviews       location no. of reviews
# 0  400.0       Biryani     4.1   Urban Estate          3,083
# 0  400.0       Mughlai     4.1   Urban Estate          3,083
# 0  400.0         Kebab     4.1   Urban Estate          3,083
# 0  400.0    Hyderabadi     4.1   Urban Estate          3,083
# 1  400.0  South Indian     4.3  Shastri Nagar          40.5K

# %%
temp["no. of reviews"] =temp["no. of reviews"].astype(str) 
def fun2(x):
    x = x.replace(",","")
    return x
temp["no. of reviews"] =temp["no. of reviews"].apply(fun2)
temp.head()
# Out:
#    price       cuisine reviews       location no. of reviews
# 0  400.0       Biryani     4.1   Urban Estate           3083
# 0  400.0       Mughlai     4.1   Urban Estate           3083
# 0  400.0         Kebab     4.1   Urban Estate           3083
# 0  400.0    Hyderabadi     4.1   Urban Estate           3083
# 1  400.0  South Indian     4.3  Shastri Nagar          40.5K

# %%
def fun3(x):
    if 'K' in x:
        x = x.replace("K","")
        x = x.split(".")[0]
        x+= '000'
    return x
fun3("40.5K")
temp["no. of reviews"] =temp["no. of reviews"].apply(fun3)
temp.head()
# Out:
#    price       cuisine reviews       location no. of reviews
# 0  400.0       Biryani     4.1   Urban Estate           3083
# 0  400.0       Mughlai     4.1   Urban Estate           3083
# 0  400.0         Kebab     4.1   Urban Estate           3083
# 0  400.0    Hyderabadi     4.1   Urban Estate           3083
# 1  400.0  South Indian     4.3  Shastri Nagar          40000

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b5ca801f6c3f> in <module>
# ----> 1 temp["cuisine"]
#
# NameError: name 'temp' is not defined

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
temp['cuisine']= label_encoder.fit_transform(temp['cuisine'])
temp['cuisine'].unique()
temp['location']= label_encoder.fit_transform(temp['location'])
temp['location'].unique()
# Out:
# array([11,  9,  6,  7,  5,  0,  1,  3,  4, 10,  2,  8])

# %%
temp.isna().sum()
temp = temp.dropna()

# %%
temp['cuisine'].unique()
# Out:
# array([50, 27, 22, 17, 74,  9, 28, 14, 39,  5, 12, 48, 68, 36, 37, 70, 75,
#        51,  6, 11, 71, 38,  3, 58, 32, 65,  7, 54, 29, 57, 18, 59, 35, 34,
#        44, 19, 49, 20, 40,  2, 24, 26,  0, 33, 72, 16, 31, 43, 23, 52, 56,
#        21,  4, 60, 10, 55, 45, 25,  8, 66, 61, 73, 67, 47, 76, 15, 46, 64,
#        42, 69, 30, 41, 13, 62, 53, 63,  1])

# %%
test = temp[temp["reviews"]=='New']
train = temp[temp["reviews"]!='New']

# %%
def dot(x):
    x = x.replace("-","0")
    return x
# test["reviews"] = test["reviews"].astype(str)
# test["reviews"] = test["reviews"].apply(dot)
# test["reviews"] = test["reviews"].astype(float)
train["reviews"] = train["reviews"].astype(str)
train["reviews"] = train["reviews"].apply(dot)
# train["reviews"] = train["reviews"].replace("",)

train["reviews"] = train["reviews"].astype(float)
# Out:
# <ipython-input-185-698529cd4d86>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["reviews"] = train["reviews"].astype(str)
# <ipython-input-185-698529cd4d86>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["reviews"] = train["reviews"].apply(dot)
# <ipython-input-185-698529cd4d86>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["reviews"] = train["reviews"].astype(float)

# %%
print(train["reviews"].value_counts())
train["no. of reviews"] = train["no. of reviews"].astype(float)
train["reviews"]=train["reviews"].replace(0,train["reviews"].mean())
train
# Out:
# 3.184418    353
# 4.000000    282
# 4.100000    226
# 3.900000    168
# 4.200000    131
# 3.800000    130
# 4.300000    114
# 3.700000     96
# 3.400000     69
# 3.500000     62
# 4.400000     60
# 3.600000     54
# 4.500000     32
# 3.300000     28
# 3.200000     24
# 3.000000     12
# 2.700000      8
# 3.100000      8
# 4.600000      6
# 2.800000      5
# 2.900000      4
# 4.700000      2
# Name: reviews, dtype: int64
# <ipython-input-220-a97578043e3e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["no. of reviews"] = train["no. of reviews"].astype(float)
# <ipython-input-220-a97578043e3e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["reviews"]=train["reviews"].replace(0,train["reviews"].mean())
#      price  cuisine  reviews  location  no. of reviews
# 0    400.0       50      4.1        11          3083.0
# 0    400.0       27      4.1        11          3083.0
# 0    400.0       22      4.1        11          3083.0
# 0    400.0       17      4.1        11          3083.0
# 1    400.0       74      4.3         9         40000.0
# ..     ...      ...      ...       ...             ...
# 641  100.0       27      3.5         9           388.0
# 642  150.0       71      4.1         9            97.0
# 642  150.0       28      4.1         9            97.0
# 644  150.0       51      4.4         9           321.0
# 644  150.0        9      4.4         9           321.0
#
# [1874 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train.drop(columns=["reviews"]), train["reviews"])
# Out:
# LinearRegression()

# %%
model.predict([[100,74,9,50000]])
# Out:
# array([4.63273889])

# %%
train["no. of reviews"].dtype
# Out:
# dtype('float64')

# %%
import statsmodels.api as smf
X=smf.add_constant(train.drop(columns=["reviews"]))
lm = smf.OLS(train["reviews"], train.drop(columns=["reviews"])).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                reviews   R-squared (uncentered):                   0.876
# Model:                            OLS   Adj. R-squared (uncentered):              0.876
# Method:                 Least Squares   F-statistic:                              3298.
# Date:                Thu, 30 Dec 2021   Prob (F-statistic):                        0.00
# Time:                        16:54:17   Log-Likelihood:                         -3209.6
# No. Observations:                1874   AIC:                                      6427.
# Df Residuals:                    1870   BIC:                                      6449.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# price              0.0077      0.000     27.914      0.000       0.007       0.008
# cuisine            0.0258      0.001     22.712      0.000       0.024       0.028
# location           0.1872      0.008     24.759      0.000       0.172       0.202
# no. of reviews  4.247e-05   5.08e-06      8.360      0.000    3.25e-05    5.24e-05
# ==============================================================================
# Omnibus:                       23.498   Durbin-Watson:                   0.688
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.915
# Skew:                          -0.265   Prob(JB):                     6.41e-06
# Kurtosis:                       2.840   Cond. No.                     1.63e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model.score(train.drop(columns=["reviews"]),train["reviews"])
# Out:
# 0.07699054582802223

# %%
from sklearn.tree import DecisionTreeRegressor
model2 = DecisionTreeRegressor(max_depth=3, criterion='mse')
model2.fit(train.drop(columns=["reviews"]), train["reviews"])
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
model2.score(train.drop(columns=["reviews"]),train["reviews"])
# Out:
# 0.7480911865064965

# %%
model2.fit()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train.drop(columns=["reviews"]),train["reviews"], test_size=0.20, random_state=10)

# %%
model2.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
model2.score(X_test,y_test)
# Out:
# 0.5860812605482051

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor
mod =RandomForestRegressor(n_estimators = 15,random_state=13)
mod.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=15, random_state=13)

# %%
mod.score(X_test,y_test)
# Out:
# 0.8481847529379515

# %%
mod.score(X_train, y_train)
# Out:
# 0.9661077253544871

# %%
mod.predict([[100,]])

# %%
mod.predict([[100,3,8,450]]).round(2)
# Out:
# array([3.89])

# %%
from sklearn.svm import SVR
regressor = SVR()
regressor.fit(X_train,y_train)
regressor.score(X_test,y_test)
regressor.score(X_train, y_train)
# Out:
# 0.29965774852741456

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {  'bootstrap': [True], 'max_depth': [5, 10, None], 'max_features': ['auto', 'log2'], 'n_estimators': [5, 6, 7, 8, 9, 10, 11, 12, 13, 15]}

# %%
rfr = RandomForestRegressor(random_state = 1)

g_search = GridSearchCV(estimator = rfr, param_grid = param_grid, 
                        cv = 3, n_jobs = 1, verbose = 0, return_train_score=True)

# %%
g_search.fit(X_train, y_train)
print(g_search.best_params_)
# Out:
# {'bootstrap': True, 'max_depth': None, 'max_features': 'auto', 'n_estimators': 15}

# %%
print(g_search.score(X_test, y_test))
# Out:
# 0.7999732582030468

# %%
print(g_search.score(X_train, y_train))
# Out:
# 0.9639606201562897

# %%
import numpy as np

from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(start = 5 , stop = 15, num = 10)] # returns 10 numbers 

max_features = ['auto', 'log2']

max_depth = [int(x) for x in np.linspace(5, 10, num = 2)] 

max_depth.append(None)

bootstrap = [True, False]

r_grid = {'n_estimators': n_estimators,

               'max_features': max_features,

               'max_depth': max_depth,

               'bootstrap': bootstrap}

print(r_grid)
# Out:
# {'n_estimators': [5, 6, 7, 8, 9, 10, 11, 12, 13, 15], 'max_features': ['auto', 'log2'], 'max_depth': [5, 10, None], 'bootstrap': [True, False]}

# %%
rfr_random = RandomizedSearchCV(estimator=rfr, param_distributions=r_grid, n_iter = 20, cv = 3, verbose=2, random_state=42, n_jobs=-1, return_train_score=True)

rfr_random.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    2.5s finished

# %%
print(rfr_random.score(X_test , y_test))
# Out:
# 0.791416055432796

# %%
print(rfr_random.score(X_train , y_train))
# Out:
# 0.9590009372092554

# %%
from sklearn.preprocessing import StandardScaler
norm_pay = StandardScaler().fit(X_train)
X_train_norm = norm_pay.transform(X_train)
X_test_norm = norm_pay.transform(X_test

# %%
mod.fit(X_train_norm, y_train)
# Out:
# RandomForestRegressor(n_estimators=15, random_state=13)

# %%
mod.score(X_train_norm, y_train)
# Out:
# 0.9667154017093147

# %%
mod.score(X_test_norm , y_test)
# Out:
# 0.7864225550621444

# %%
jal['cuisine']
# Out:
# 0                    Biryani, Mughlai, Kebab, Hyderabadi
# 1      South Indian, Chinese, North Indian, Fast Food...
# 2                                Biryani, Kebab, Mughlai
# 3                  Bakery, Chinese, Fast Food, Beverages
# 4                North Indian, Mughlai, Chinese, Seafood
#                              ...
# 640                                         North Indian
# 641                                North Indian, Mughlai
# 642                                  Rolls, North Indian
# 643                               Street Food, Fast Food
# 644                                      Burger, Chinese
# Name: cuisine, Length: 645, dtype: object

# %%
jal.assign(cuisine = jal['cuisine'].str.split(',')).explode('cuisine')
# Out:
#                  name         price        cuisine reviews  \
# 0     Biryani By Kilo  ?400 for one        Biryani     4.1
# 0     Biryani By Kilo  ?400 for one        Mughlai     4.1
# 0     Biryani By Kilo  ?400 for one          Kebab     4.1
# 0     Biryani By Kilo  ?400 for one     Hyderabadi     4.1
# 1          Food Bazar  ?400 for one   South Indian     4.3
# ..                ...           ...            ...     ...
# 642      Veggie Chaap  ?150 for one   North Indian     4.1
# 643   Bombay Chaupati           NaN    Street Food     3.9
# 643   Bombay Chaupati           NaN      Fast Food     3.9
# 644  Sehgal Fast Food  ?150 for one         Burger     4.4
# 644  Sehgal Fast Food  ?150 for one        Chinese     4.4
#
#                                           Location url       location  \
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 0    https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 1    https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# ..                                                 ...            ...
# 642  https://www.zomato.com/jalandhar/veggie-chaap-...  Shastri Nagar
# 643  https://www.zomato.com/jalandhar/bombay-chaupa...     Model Town
# 643  https://www.zomato.com/jalandhar/bombay-chaupa...     Model Town
# 644  https://www.zomato.com/jalandhar/sehgal-fast-f...  Shastri Nagar
# 644  https://www.zomato.com/jalandhar/sehgal-fast-f...  Shastri Nagar
#
#     no. of reviews
# 0            3,083
# 0            3,083
# 0            3,083
# 0            3,083
# 1            40.5K
# ..             ...
# 642             97
# 643            175
# 643            175
# 644            321
# 644            321
#
# [1977 rows x 7 columns]

# %%
jal[jal['cuisine']=='Beverage']
# Out:
# Empty DataFrame
# Columns: [name, price, cuisine, reviews, Location url, location, no. of reviews]
# Index: []

# %%
jal.assign(cuisine = jal['cuisine'].str.split(',')).explode('cuisine')["cuisine"].unique()
# Out:
# array(['Biryani', ' Mughlai', ' Kebab', ' Hyderabadi', 'South Indian',
#        ' Chinese', ' North Indian', ' Fast Food', ' Street Food',
#        ' Beverages', ' Desserts', 'Bakery', 'North Indian', ' Seafood',
#        ' Shake', 'Pizza', 'Street Food', 'Burger', ' Biryani',
#        ' Continental', 'Rolls', ' South Indian', ' BBQ', 'Fast Food',
#        ' Pizza', 'Mithai', ' Burger', 'Chinese', ' Oriental', 'Desserts',
#        ' Ice Cream', 'Healthy Food', ' Sandwich', ' Salad', ' Wraps',
#        ' Italian', 'Beverages', ' Japanese', ' Sushi', ' Asian',
#        ' Mexican', ' Momos', ' American', ' Rolls', 'Salad',
#        ' Healthy Food', ' Pasta', ' Waffle', ' Lebanese', 'Cafe',
#        'Continental', ' Juices', ' Bakery', 'Ice Cream', ' Coffee',
#        'Coffee', 'American', ' Mithai', ' Cafe', 'Momos', 'Italian',
#        'Sandwich', 'Mughlai', 'BBQ', 'Tibetan', ' Finger Food', 'Asian',
#        'Mexican', ' Thai', 'Pasta', ' Panini', ' Tea', ' European',
#        'Juices', 'Charcoal Chicken', 'Lebanese', ' Arabian'], dtype=object)

# %%
import pandas as pd
import json
df = pd.read_csv("C:\\Users\\Lenovo\\Data Science\\Zomato_Github_Download\\Zomato_Restaurant_Rating_Prediction-main/jalandhar_zomato.csv")
df
# Out:
#                   name         price       cuisine reviews  \
# 0      Biryani By Kilo  ?400 for one       Biryani     4.1
# 1      Biryani By Kilo  ?400 for one       Mughlai     4.1
# 2      Biryani By Kilo  ?400 for one         Kebab     4.1
# 3      Biryani By Kilo  ?400 for one    Hyderabadi     4.1
# 4           Food Bazar  ?400 for one  South Indian     4.3
# ...                ...           ...           ...     ...
# 1972      Veggie Chaap  ?150 for one  North Indian     4.1
# 1973   Bombay Chaupati           NaN   Street Food     3.9
# 1974   Bombay Chaupati           NaN     Fast Food     3.9
# 1975  Sehgal Fast Food  ?150 for one        Burger     4.4
# 1976  Sehgal Fast Food  ?150 for one       Chinese     4.4
#
#                                            Location url       location  \
# 0     https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 1     https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 2     https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 3     https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 4     https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# ...                                                 ...            ...
# 1972  https://www.zomato.com/jalandhar/veggie-chaap-...  Shastri Nagar
# 1973  https://www.zomato.com/jalandhar/bombay-chaupa...     Model Town
# 1974  https://www.zomato.com/jalandhar/bombay-chaupa...     Model Town
# 1975  https://www.zomato.com/jalandhar/sehgal-fast-f...  Shastri Nagar
# 1976  https://www.zomato.com/jalandhar/sehgal-fast-f...  Shastri Nagar
#
#      no. of reviews       City
# 0             3,083  Jalandhar
# 1             3,083  Jalandhar
# 2             3,083  Jalandhar
# 3             3,083  Jalandhar
# 4             40.5K  Jalandhar
# ...             ...        ...
# 1972             97  Jalandhar
# 1973            175  Jalandhar
# 1974            175  Jalandhar
# 1975            321  Jalandhar
# 1976            321  Jalandhar
#
# [1977 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(df["City"])
# Out:
# LabelEncoder()

# %%
df["City"] = le.fit_transform(df["City"])
label_encoding_dict = dict()
for num, label in enumerate(le.classes_):
    label_encoding_dict[label] = num 
print(json.dumps(label_encoding_dict, indent = 4))
# Out:
# {
#     "Jalandhar": 0
# }

# %%
city_d = json.dumps(label_encoding_dict, indent = 4)
print(city_d)
# Out:
# {
#     "Jalandhar": 0
# }

# %%
s = le.fit_transform(df["cuisine"])
label_encoding_dict = dict()
for num, label in enumerate(le.classes_):
    label_encoding_dict[label] = num 
print(json.dumps(label_encoding_dict, indent = 4))
# Out:
# {
#     "American": 0,
#     "Arabian": 1,
#     "Asian": 2,
#     "BBQ": 3,
#     "Bakery": 4,
#     "Beverages": 5,
#     "Biryani": 6,
#     "Burger": 7,
#     "Cafe": 8,
#     "Charcoal Chicken": 9,
#     "Chinese": 10,
#     "Coffee": 11,
#     "Continental": 12,
#     "Desserts": 13,
#     "European": 14,
#     "Fast Food": 15,
#     "Finger Food": 16,
#     "Healthy Food": 17,
#     "Hyderabadi": 18,
#     "Ice Cream": 19,
#     "Italian": 20,
#     "Japanese": 21,
#     "Juices": 22,
#     "Kebab": 23,
#     "Lebanese": 24,
#     "Mexican": 25,
#     "Mithai": 26,
#     "Momos": 27,
#     "Mughlai": 28,
#     "North Indian": 29,
#     "Oriental": 30,
#     "Panini": 31,
#     "Pasta": 32,
#     "Pizza": 33,
#     "Rolls": 34,
#     "Salad": 35,
#     "Sandwich": 36,
#     "Seafood": 37,
#     "Shake": 38,
#     "South Indian": 39,
#     "Street Food": 40,
#     "Sushi": 41,
#     "Tea": 42,
#     "Thai": 43,
#     "Tibetan": 44,
#     "Waffle": 45,
#     "Wraps": 46
# }

# %%
s = le.fit_transform(df["location"])
label_encoding_dict = dict()
for num, label in enumerate(le.classes_):
    label_encoding_dict[label] = num 
print(json.dumps(label_encoding_dict, indent = 4))
# Out:
# {
#     "Adarsh Nagar": 0,
#     "GT Road": 1,
#     "Jalandhar Cantt": 2,
#     "Maqsudan": 3,
#     "Model House": 4,
#     "Model Town": 5,
#     "Nakodar Road": 6,
#     "PPR Market": 7,
#     "Rama Mandi": 8,
#     "Shastri Nagar": 9,
#     "Transport Nagar": 10,
#     "Urban Estate": 11
# }

# %% [markdown]
# # More relevant part

# %%
temp = df

# %%
temp.drop(columns=["name","Location url"],inplace=True)

# %%
def fun(x):
    x = x.replace("?","")
    x =x.replace(" for one","")
    return x
temp["price"] = temp["price"].astype(str)
temp["price"] = temp["price"].apply(fun)
temp["price"] = temp["price"].astype(float)
temp.head()
# Out:
#    price       cuisine reviews       location no. of reviews  City
# 0  400.0       Biryani     4.1   Urban Estate          3,083     0
# 1  400.0       Mughlai     4.1   Urban Estate          3,083     0
# 2  400.0         Kebab     4.1   Urban Estate          3,083     0
# 3  400.0    Hyderabadi     4.1   Urban Estate          3,083     0
# 4  400.0  South Indian     4.3  Shastri Nagar          40.5K     0

# %%
temp["no. of reviews"] =temp["no. of reviews"].astype(str) 
def fun2(x):
    x = x.replace(",","")
    return x
temp["no. of reviews"] =temp["no. of reviews"].apply(fun2)
temp.head()
# Out:
#    price       cuisine reviews       location no. of reviews  City
# 0  400.0       Biryani     4.1   Urban Estate           3083     0
# 1  400.0       Mughlai     4.1   Urban Estate           3083     0
# 2  400.0         Kebab     4.1   Urban Estate           3083     0
# 3  400.0    Hyderabadi     4.1   Urban Estate           3083     0
# 4  400.0  South Indian     4.3  Shastri Nagar          40.5K     0

# %%
def fun3(x):
    if 'K' in x:
        x = x.replace("K","")
        x = x.split(".")[0]
        x+= '000'
    return x
fun3("40.5K")
temp["no. of reviews"] =temp["no. of reviews"].apply(fun3)
temp.head()
# Out:
#    price       cuisine reviews       location no. of reviews  City
# 0  400.0       Biryani     4.1   Urban Estate           3083     0
# 1  400.0       Mughlai     4.1   Urban Estate           3083     0
# 2  400.0         Kebab     4.1   Urban Estate           3083     0
# 3  400.0    Hyderabadi     4.1   Urban Estate           3083     0
# 4  400.0  South Indian     4.3  Shastri Nagar          40000     0

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
temp['cuisine']= label_encoder.fit_transform(temp['cuisine'])
temp['cuisine'].unique()
temp['location']= label_encoder.fit_transform(temp['location'])
temp['location'].unique()
temp["reviews"].unique()
# Out:
# array(['4.1', '4.3', '3.9', '4', '3.8', '3.6', '4.2', '4.4', '3.7', '3.5',
#        '4.5', '3.2', '3.4', '3.3', '4.6', '-', 'New', '3.1', '2.8', '3',
#        '4.7', '2.9', '2.7'], dtype=object)

# %%
temp.isna().sum()
temp = temp.dropna()

# %%
# def dot(x):
#     x = x.replace("-", "0")
#     return x

# temp[temp["reviews"]!='New'].unique()

# temp["reviews"] = temp["reviews"].astype(str)
# temp["reviews"] = temp["reviews"].apply(dot)
temp["reviews"] = temp["reviews"].replace("-",0)
temp
# temp["reviews"] = temp["reviews"].astype(float)
temp["reviews"].unique()
temp = temp[temp["reviews"]!='New']
temp["reviews"] = temp["reviews"].astype(float)

temp["reviews"] = temp["reviews"].replace(0,temp["reviews"].mean())
temp
# Out:
# <ipython-input-288-6bade46a6510>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["reviews"] = temp["reviews"].replace("-",0)
#       price  cuisine  reviews  location no. of reviews  City
# 0     400.0        6      4.1        11           3083     0
# 1     400.0       28      4.1        11           3083     0
# 2     400.0       23      4.1        11           3083     0
# 3     400.0       18      4.1        11           3083     0
# 4     400.0       39      4.3         9          40000     0
# ...     ...      ...      ...       ...            ...   ...
# 1970  100.0       28      3.5         9            388     0
# 1971  150.0       34      4.1         9             97     0
# 1972  150.0       29      4.1         9             97     0
# 1975  150.0        7      4.4         9            321     0
# 1976  150.0       10      4.4         9            321     0
#
# [1874 rows x 6 columns]

# %%
print(temp["reviews"].value_counts())
temp["no. of reviews"] = temp["no. of reviews"].astype(float)
temp["reviews"]=temp["reviews"].replace(0,temp["reviews"].mean())
temp
# Out:
# 3.184418    353
# 4.000000    282
# 4.100000    226
# 3.900000    168
# 4.200000    131
# 3.800000    130
# 4.300000    114
# 3.700000     96
# 3.400000     69
# 3.500000     62
# 4.400000     60
# 3.600000     54
# 4.500000     32
# 3.300000     28
# 3.200000     24
# 3.000000     12
# 2.700000      8
# 3.100000      8
# 4.600000      6
# 2.800000      5
# 2.900000      4
# 4.700000      2
# Name: reviews, dtype: int64
#       price  cuisine  reviews  location  no. of reviews  City
# 0     400.0        6      4.1        11          3083.0     0
# 1     400.0       28      4.1        11          3083.0     0
# 2     400.0       23      4.1        11          3083.0     0
# 3     400.0       18      4.1        11          3083.0     0
# 4     400.0       39      4.3         9         40000.0     0
# ...     ...      ...      ...       ...             ...   ...
# 1970  100.0       28      3.5         9           388.0     0
# 1971  150.0       34      4.1         9            97.0     0
# 1972  150.0       29      4.1         9            97.0     0
# 1975  150.0        7      4.4         9           321.0     0
# 1976  150.0       10      4.4         9           321.0     0
#
# [1874 rows x 6 columns]

# %%
import statsmodels.api as smf
X=smf.add_constant(temp.drop(columns=["reviews"]))
lm = smf.OLS(temp["reviews"], temp.drop(columns=["reviews"])).fit()
lm.summary()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1860: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                reviews   R-squared (uncentered):                   0.886
# Model:                            OLS   Adj. R-squared (uncentered):              0.886
# Method:                 Least Squares   F-statistic:                              3644.
# Date:                Sat, 15 Jan 2022   Prob (F-statistic):                        0.00
# Time:                        13:34:02   Log-Likelihood:                         -3127.2
# No. Observations:                1874   AIC:                                      6262.
# Df Residuals:                    1870   BIC:                                      6284.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# price              0.0067      0.000     24.085      0.000       0.006       0.007
# cuisine            0.0573      0.002     27.116      0.000       0.053       0.061
# location           0.1734      0.007     23.710      0.000       0.159       0.188
# no. of reviews  3.814e-05   4.87e-06      7.838      0.000    2.86e-05    4.77e-05
# City                    0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       14.378   Durbin-Watson:                   0.793
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.363
# Skew:                          -0.198   Prob(JB):                     0.000761
# Kurtosis:                       2.837   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
temp.columns = ["Price","Cuisine","Ratings","Location","No. of Reviews","City"]
temp.head()
# Out:
#    Price  Cuisine  Ratings  Location  No. of Reviews  City
# 0  400.0        6      4.1        11          3083.0     0
# 1  400.0       28      4.1        11          3083.0     0
# 2  400.0       23      4.1        11          3083.0     0
# 3  400.0       18      4.1        11          3083.0     0
# 4  400.0       39      4.3         9         40000.0     0

# %%
temp = temp[['City', 'Location', 'Cuisine', 'Ratings', 'No. of Reviews','Price']]
temp.head()
# Out:
#    City  Location  Cuisine  Ratings  No. of Reviews  Price
# 0     0        11        6      4.1          3083.0  400.0
# 1     0        11       28      4.1          3083.0  400.0
# 2     0        11       23      4.1          3083.0  400.0
# 3     0        11       18      4.1          3083.0  400.0
# 4     0         9       39      4.3         40000.0  400.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(temp.drop(columns=["Ratings"]),temp["Ratings"], test_size=0.2, random_state=10001)

# %%
from sklearn.preprocessing import StandardScaler
norm_pay = StandardScaler().fit(X_train)
X_train_norm = norm_pay.transform(X_train)
X_test_norm = norm_pay.transform(X_test)

# %%
import numpy as np

from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(start = 5 , stop = 15, num = 10)] # returns 10 numbers 

max_features = ['auto', 'log2']

max_depth = [int(x) for x in np.linspace(5, 10, num = 2)] 

max_depth.append(None)

bootstrap = [True, False]

r_grid = {'n_estimators': n_estimators,

               'max_features': max_features,

               'max_depth': max_depth,

               'bootstrap': bootstrap}

print(r_grid)
# Out:
# {'n_estimators': [5, 6, 7, 8, 9, 10, 11, 12, 13, 15], 'max_features': ['auto', 'log2'], 'max_depth': [5, 10, None], 'bootstrap': [True, False]}

# %%
rfr = RandomForestRegressor(random_state = 1)
from sklearn.model_selection import GridSearchCV
g_search = GridSearchCV(estimator = rfr, param_grid = r_grid, 
                        cv = 3, n_jobs = 1, verbose = 0, return_train_score=True)

# %%
rfr_random = RandomizedSearchCV(estimator=rfr, param_distributions=r_grid, n_iter = 20, cv = 3, verbose=2, random_state=42, n_jobs=-1, return_train_score=True)

rfr_random.fit(X_train, y_train);
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    7.1s finished

# %%
print(rfr_random.score(X_train, y_train))
rfr_random.score(X_test, y_test)
# Out:
# 0.9660920694606755
# 0.803010634181768

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor
mod =RandomForestRegressor(n_estimators = 300,random_state=48, max_depth=12,min_samples_leaf=3)
mod.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=12, min_samples_leaf=3, n_estimators=300,
#                       random_state=48)

# %%
mod.score(X_train, y_train)
# Out:
# 0.8747157502007119

# %%
mod.score(X_test, y_test)
# Out:
# 0.7115675448391837

# %%
import bz2
import pickle
with open('model_pickle','wb') as file:
    pickle.dump(mod,file)
# sfile = bz2.BZ2File('C:\\Users\\Lenovo\\Data Science\\Zomato_Github_Download\\Zomato_Restaurant_Rating_Prediction-main\\bestmodel\\RandomforestRegressors.pkl', 'wb')
# pickle.dump(mod, sfile)

# %%
# df = pd.read_csv("C:\\Users\\Lenovo\\Data Science\\Zomato_Github_Download\\Zomato_Restaurant_Rating_Prediction-main/jalandhar_zomato.csv")
# df

# %%
s = df["cuisine"].unique()

# %%
s.sort()
cuisine = pd.DataFrame(s)
cuisine.columns = ["Cuisine"]
cuisine.head()
# Out:
#    Cuisine
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4

# %%
# s = le.fit_transform(temp["Cuisine"])
# label_encoding_dict = dict()
# for num, label in enumerate(le.classes_):
#     label_encoding_dict[label] = num 
# cuisine_json = json.dumps(label_encoding_dict,indent=4)
# print(cuisine_json)

# %%
s = df["City"].unique()
s.sort()
city = pd.DataFrame(s)
city.columns = ["Cuisine"]
city.head()
# Out:
#    Cuisine
# 0        0

# %%
s = le.fit_transform(df["City"])
label_encoding_dict = dict()
for num, label in enumerate(le.classes_):
    label_encoding_dict[label] = num 
city_json = json.dumps(label_encoding_dict, indent=4)
print(city_json)
# Out:
# {
#     "Jalandhar": 0
# }

# %%
temp
# Out:
#       City  Location  Cuisine  Ratings  No. of Reviews  Price
# 0        0        11        6      4.1          3083.0  400.0
# 1        0        11       28      4.1          3083.0  400.0
# 2        0        11       23      4.1          3083.0  400.0
# 3        0        11       18      4.1          3083.0  400.0
# 4        0         9       39      4.3         40000.0  400.0
# ...    ...       ...      ...      ...             ...    ...
# 1970     0         9       28      3.5           388.0  100.0
# 1971     0         9       34      4.1            97.0  150.0
# 1972     0         9       29      4.1            97.0  150.0
# 1975     0         9        7      4.4           321.0  150.0
# 1976     0         9       10      4.4           321.0  150.0
#
# [1874 rows x 6 columns]

# %%
temp.to_csv("zomato_final_data.csv")

# %%
df = pd.read_csv("C:\\Users\\Lenovo\\Data Science\\Zomato_Github_Download\\Zomato_Restaurant_Rating_Prediction-main/jalandhar_zomato.csv")
df
# Out:
#                   name         price       cuisine reviews  \
# 0      Biryani By Kilo  ?400 for one       Biryani     4.1
# 1      Biryani By Kilo  ?400 for one       Mughlai     4.1
# 2      Biryani By Kilo  ?400 for one         Kebab     4.1
# 3      Biryani By Kilo  ?400 for one    Hyderabadi     4.1
# 4           Food Bazar  ?400 for one  South Indian     4.3
# ...                ...           ...           ...     ...
# 1972      Veggie Chaap  ?150 for one  North Indian     4.1
# 1973   Bombay Chaupati           NaN   Street Food     3.9
# 1974   Bombay Chaupati           NaN     Fast Food     3.9
# 1975  Sehgal Fast Food  ?150 for one        Burger     4.4
# 1976  Sehgal Fast Food  ?150 for one       Chinese     4.4
#
#                                            Location url       location  \
# 0     https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 1     https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 2     https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 3     https://www.zomato.com/jalandhar/biryani-by-ki...   Urban Estate
# 4     https://www.zomato.com/jalandhar/food-bazar-sh...  Shastri Nagar
# ...                                                 ...            ...
# 1972  https://www.zomato.com/jalandhar/veggie-chaap-...  Shastri Nagar
# 1973  https://www.zomato.com/jalandhar/bombay-chaupa...     Model Town
# 1974  https://www.zomato.com/jalandhar/bombay-chaupa...     Model Town
# 1975  https://www.zomato.com/jalandhar/sehgal-fast-f...  Shastri Nagar
# 1976  https://www.zomato.com/jalandhar/sehgal-fast-f...  Shastri Nagar
#
#      no. of reviews       City
# 0             3,083  Jalandhar
# 1             3,083  Jalandhar
# 2             3,083  Jalandhar
# 3             3,083  Jalandhar
# 4             40.5K  Jalandhar
# ...             ...        ...
# 1972             97  Jalandhar
# 1973            175  Jalandhar
# 1974            175  Jalandhar
# 1975            321  Jalandhar
# 1976            321  Jalandhar
#
# [1977 rows x 8 columns]

# %%
temp.dtypes
# Out:
# City                int32
# Location            int32
# Cuisine             int32
# Ratings           float64
# No. of Reviews    float64
# dtype: object

# %%
temp.columns
# Out:
# Index(['City', 'Location', 'Cuisine', 'Ratings', 'No. of Reviews'], dtype='object')
